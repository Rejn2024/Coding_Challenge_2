# %% [markdown]
# ## Importing Packages/Functions

# %%
import torch
import torchvision
import utils
import os
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import engine
from joblib import dump, load
from importlib import reload
from torch.utils.tensorboard import SummaryWriter
# %load_ext tensorboard


def custom_target_save(target, folder_name):
    os.mkdir(folder_name)
    
    for k, v in target.items():
        if isinstance(v, tv_tensors.BoundingBoxes):
            torch.save(v, f'{folder_name}/{k}.pt')
        elif isinstance(v, torch.Tensor):
            torch.save(v, f'{folder_name}/{k}.pt')
        else:    
            dump(v, f'{folder_name}/{k}')
            
    return True

def custom_target_load(folder_name):
    target ={}
    
    target['area'] = load(f'{folder_name}/area')
    target['iscrowd'] = torch.load(f'{folder_name}/iscrowd.pt').to(torch.int64)
    target['labels'] = torch.load(f'{folder_name}/labels.pt').to(torch.int64)
    target['boxes'] = torch.load(f'{folder_name}/boxes.pt').float()
    target['image_id'] = load(f'{folder_name}/image_id')
    
            
    return target

# %% [markdown]
# ## Note: as discused in previous interviews, my experience with PyTorch is limited. Much of this work has been derived from  [this](https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html) tutorial. Notably, the [utils](https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py), [engine](https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py), [transforms](https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py), [coco_utils](https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py) and [coco_eval ](https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py) modules have been downloaded and used as-is, with the exception of engine, which has been lightly modified for the validation step in the training loop.

# %% [markdown]
# ## Data Loaders

# %%
### Construct Data Loader

class Aug_CHR_Dataset(torch.utils.data.Dataset):
    def __init__(self, 
                 augmented_folder,
                 ):
        self.augmented_folder = augmented_folder 
        self.uus = list(os.listdir(f'{self.augmented_folder}//Images'))
    

    def __getitem__(self, idx):
        img = torch.load(f'{self.augmented_folder}//Images//{self.uus[idx]}').float()
        target= custom_target_load(f'{self.augmented_folder}//Targets//{self.uus[idx]}')
        
        return img, target

    def __len__(self):
        return len(self.uus)


batch_size = 2


aug_train_data = Aug_CHR_Dataset('augmented_balanced_data\\Training_Data')
aug_val_data = Aug_CHR_Dataset('augmented_balanced_data\\Val_Data')

aug_train_data_loader = torch.utils.data.DataLoader(
    aug_train_data,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=utils.collate_fn
)


aug_val_data_loader = torch.utils.data.DataLoader(
    aug_val_data,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=utils.collate_fn
)

# %% [markdown]
# ## Model

# %%
num_classes = 4 ## three species plus "crowd" 
 
## Firweall issues have prevented me from a direct download, requiring the following work around
foundation_model_weights = torch.load('fasterrcnn_resnet50_fpn_coco-258fb6c6.pth') 
foundation_model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained_backbone=False)
foundation_model.load_state_dict(foundation_model_weights)

## constrcut the desired mode and consign to gpu
def get_model(model,
              num_classes):
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, 
                                                      num_classes)

    # now get the number of input features for the mask classifier
    model.cuda()
    return model

## build classifier and bounding box model

local_model = get_model(foundation_model,
                        num_classes)
# Out:
# C:\Users\richard.nicklin\AppData\Roaming\Python\Python310\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained_backbone' is deprecated since 0.13 and may be removed in the future, please use 'weights_backbone' instead.
#   warnings.warn(
# C:\Users\richard.nicklin\AppData\Roaming\Python\Python310\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights_backbone' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights_backbone=None`.
#   warnings.warn(msg)

# %%
## Define training loop
params = [p for p in local_model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)



# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)


def training_loop(model, 
                  trainloader, 
                  valloader, 
                  optimizer,
                  save_name,
                  device,
                  epochs=2): 
     
    tb = SummaryWriter(f'logs/fit')
    best_loss = torch.inf
   
    ## losses/metrics to monitor in tensorboard
    
    toe_keys = ['lr', 'loss',
                'loss_classifier', 'loss_box_reg',
                'loss_objectness', 'loss_rpn_box_reg']
    
    output_dict = {'Training' : {},
                   'Validation' : {}}
    
    for tk in toe_keys:
        for v in output_dict.values():
            v[f'{tk}_Median'] = []
            v[f'{tk}_First_Quartile'] = []
            v[f'{tk}_Third_Quartile'] = []
            v[f'{tk}_Mean'] = []
        
    
    for epoch in range(epochs): 
        print(f'Epoch {epoch}/{epochs - 1}')
        print('-' * 10)
        evals ={} 
        model = model.to(device)
        print('train:')
        evals['Training']  = engine.engage_one_epoch(model, 
                                optimizer, 
                                trainloader, 
                                device, 
                                epoch, 
                                print_freq=10, 
                                train = True)
        print('val:')
        evals['Validation']  = engine.engage_one_epoch(model, 
                                optimizer, 
                                valloader, 
                                device, 
                                epoch, 
                                print_freq=10, 
                                train = False)
        for k,v in evals.items():
            for tk in toe_keys:
                
                med = v.meters[tk].median
                q1 = v.meters[tk].first_quartile
                q3 = v.meters[tk].third_quartile
                mu = v.meters[tk].avg
                
                tb.add_scalar(f'{tk}/{k}_Median',
                            med,
                            epoch)
                tb.add_scalar(f'{tk}/{k}_First_Quartile',
                            q1,
                            epoch)
                tb.add_scalar(f'{tk}/{k}_Third_Quartile',
                            q3,
                            epoch)
                tb.add_scalar(f'{tk}/{k}_Mean',
                            mu,
                            epoch)
                
                output_dict[k][f'{tk}_Median'].append(med)
                output_dict[k][f'{tk}_First_Quartile'].append(q1)
                output_dict[k][f'{tk}_Third_Quartile'].append(q3)
                output_dict[k][f'{tk}_Mean'].append(mu)
                
        bl = evals['Validation'].meters['loss_classifier'].median
        if  bl < best_loss:
            best_loss = bl
            torch.save(local_model, save_name)
        
    tb.close()
    
    return tb, output_dict

# %%
## Launch Tensorboard
# %tensorboard --logdir='logs/fit'
# Out:
# Reusing TensorBoard on port 6006 (pid 15820), started 4:52:22 ago. (Use '!kill 15820' to kill it.)
#       <iframe id="tensorboard-frame-5fc8d72028f835be" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5fc8d72028f835be");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
tl, od = training_loop(local_model, 
                       aug_train_data_loader, 
                       aug_val_data_loader, 
                       optimizer,
                       save_name = 'Models/CHR_ResNet',
                       device = torch.device('cuda'),
                       epochs=2)

dump(od, 'training_output')
# Out:
# Epoch 0/1
# ----------
# train:
# Epoch: [0]  [  0/546]  eta: 0:26:38  lr: 0.000014  loss: 2.4146 (2.4146)  loss_classifier: 1.4738 (1.4738)  loss_box_reg: 0.0026 (0.0026)  loss_objectness: 0.8179 (0.8179)  loss_rpn_box_reg: 0.1203 (0.1203)  time: 2.9283  data: 0.0519  max mem: 4017
# Epoch: [0]  [ 10/546]  eta: 0:42:17  lr: 0.000106  loss: 2.1408 (2.1331)  loss_classifier: 1.3907 (1.3635)  loss_box_reg: 0.0341 (0.0326)  loss_objectness: 0.7149 (0.6687)  loss_rpn_box_reg: 0.0671 (0.0683)  time: 4.7333  data: 0.0187  max mem: 6241
# Epoch: [0]  [ 20/546]  eta: 0:39:56  lr: 0.000197  loss: 1.5982 (1.5985)  loss_classifier: 0.9789 (1.0051)  loss_box_reg: 0.0381 (0.0413)  loss_objectness: 0.4287 (0.4821)  loss_rpn_box_reg: 0.0587 (0.0700)  time: 4.6382  data: 0.0170  max mem: 6241
# Epoch: [0]  [ 30/546]  eta: 0:38:54  lr: 0.000289  loss: 0.6635 (1.2385)  loss_classifier: 0.3384 (0.7539)  loss_box_reg: 0.0781 (0.0657)  loss_objectness: 0.1029 (0.3529)  loss_rpn_box_reg: 0.0553 (0.0661)  time: 4.4098  data: 0.0195  max mem: 6241
# Epoch: [0]  [ 40/546]  eta: 0:37:38  lr: 0.000381  loss: 0.3975 (1.0389)  loss_classifier: 0.1871 (0.6181)  loss_box_reg: 0.1067 (0.0819)  loss_objectness: 0.0509 (0.2768)  loss_rpn_box_reg: 0.0434 (0.0621)  time: 4.3651  data: 0.0192  max mem: 6241
# Epoch: [0]  [ 50/546]  eta: 0:38:41  lr: 0.000472  loss: 0.3844 (0.9069)  loss_classifier: 0.1688 (0.5300)  loss_box_reg: 0.1281 (0.0903)  loss_objectness: 0.0338 (0.2289)  loss_rpn_box_reg: 0.0354 (0.0577)  time: 4.9233  data: 0.0192  max mem: 7201
# Epoch: [0]  [ 60/546]  eta: 0:38:25  lr: 0.000564  loss: 0.3600 (0.8117)  loss_classifier: 0.1514 (0.4651)  loss_box_reg: 0.1313 (0.0970)  loss_objectness: 0.0238 (0.1961)  loss_rpn_box_reg: 0.0354 (0.0536)  time: 5.3161  data: 0.0215  max mem: 7201
# Epoch: [0]  [ 70/546]  eta: 0:38:02  lr: 0.000656  loss: 0.3101 (0.7431)  loss_classifier: 0.1149 (0.4159)  loss_box_reg: 0.1247 (0.1027)  loss_objectness: 0.0180 (0.1723)  loss_rpn_box_reg: 0.0321 (0.0522)  time: 5.0897  data: 0.0219  max mem: 7201
# Epoch: [0]  [ 80/546]  eta: 0:38:07  lr: 0.000747  loss: 0.2727 (0.6848)  loss_classifier: 0.0902 (0.3763)  loss_box_reg: 0.1121 (0.1049)  loss_objectness: 0.0144 (0.1530)  loss_rpn_box_reg: 0.0273 (0.0506)  time: 5.4107  data: 0.0215  max mem: 7427
# Epoch: [0]  [ 90/546]  eta: 0:37:38  lr: 0.000839  loss: 0.2422 (0.6333)  loss_classifier: 0.0733 (0.3428)  loss_box_reg: 0.0974 (0.1031)  loss_objectness: 0.0123 (0.1381)  loss_rpn_box_reg: 0.0245 (0.0493)  time: 5.5104  data: 0.0215  max mem: 8556
# Epoch: [0]  [100/546]  eta: 0:37:07  lr: 0.000931  loss: 0.2017 (0.5997)  loss_classifier: 0.0703 (0.3200)  loss_box_reg: 0.0974 (0.1070)  loss_objectness: 0.0114 (0.1254)  loss_rpn_box_reg: 0.0236 (0.0473)  time: 5.3497  data: 0.0182  max mem: 8556
# Epoch: [0]  [110/546]  eta: 0:35:52  lr: 0.001022  loss: 0.1953 (0.5639)  loss_classifier: 0.0680 (0.2976)  loss_box_reg: 0.1012 (0.1063)  loss_objectness: 0.0093 (0.1150)  loss_rpn_box_reg: 0.0185 (0.0450)  time: 4.8644  data: 0.0188  max mem: 8556
# Epoch: [0]  [120/546]  eta: 0:35:24  lr: 0.001114  loss: 0.2050 (0.5391)  loss_classifier: 0.0629 (0.2801)  loss_box_reg: 0.0985 (0.1073)  loss_objectness: 0.0109 (0.1068)  loss_rpn_box_reg: 0.0221 (0.0448)  time: 4.9433  data: 0.0195  max mem: 8556
# Epoch: [0]  [130/546]  eta: 0:34:54  lr: 0.001206  loss: 0.2149 (0.5160)  loss_classifier: 0.0629 (0.2646)  loss_box_reg: 0.0985 (0.1074)  loss_objectness: 0.0107 (0.0993)  loss_rpn_box_reg: 0.0315 (0.0447)  time: 5.5729  data: 0.0177  max mem: 8556
# Epoch: [0]  [140/546]  eta: 0:33:33  lr: 0.001297  loss: 0.1986 (0.4956)  loss_classifier: 0.0617 (0.2511)  loss_box_reg: 0.0971 (0.1070)  loss_objectness: 0.0096 (0.0931)  loss_rpn_box_reg: 0.0280 (0.0444)  time: 4.7863  data: 0.0202  max mem: 8556
# Epoch: [0]  [150/546]  eta: 0:32:47  lr: 0.001389  loss: 0.1917 (0.4763)  loss_classifier: 0.0618 (0.2387)  loss_box_reg: 0.0844 (0.1061)  loss_objectness: 0.0096 (0.0876)  loss_rpn_box_reg: 0.0240 (0.0438)  time: 4.5284  data: 0.0202  max mem: 8556
# Epoch: [0]  [160/546]  eta: 0:32:03  lr: 0.001481  loss: 0.1931 (0.4612)  loss_classifier: 0.0618 (0.2284)  loss_box_reg: 0.0826 (0.1059)  loss_objectness: 0.0088 (0.0827)  loss_rpn_box_reg: 0.0242 (0.0441)  time: 5.1505  data: 0.0184  max mem: 8556
# Epoch: [0]  [170/546]  eta: 0:31:31  lr: 0.001572  loss: 0.1931 (0.4467)  loss_classifier: 0.0647 (0.2194)  loss_box_reg: 0.0989 (0.1060)  loss_objectness: 0.0076 (0.0783)  loss_rpn_box_reg: 0.0317 (0.0431)  time: 5.5136  data: 0.0185  max mem: 8558
# Epoch: [0]  [180/546]  eta: 0:30:54  lr: 0.001664  loss: 0.1885 (0.4362)  loss_classifier: 0.0647 (0.2122)  loss_box_reg: 0.1027 (0.1071)  loss_objectness: 0.0073 (0.0746)  loss_rpn_box_reg: 0.0163 (0.0423)  time: 5.7536  data: 0.0175  max mem: 8558
# Epoch: [0]  [190/546]  eta: 0:30:10  lr: 0.001756  loss: 0.2500 (0.4288)  loss_classifier: 0.0830 (0.2065)  loss_box_reg: 0.1334 (0.1095)  loss_objectness: 0.0077 (0.0711)  loss_rpn_box_reg: 0.0185 (0.0417)  time: 5.5452  data: 0.0185  max mem: 8558
# Epoch: [0]  [200/546]  eta: 0:29:51  lr: 0.001847  loss: 0.2495 (0.4192)  loss_classifier: 0.0746 (0.1997)  loss_box_reg: 0.1259 (0.1090)  loss_objectness: 0.0059 (0.0679)  loss_rpn_box_reg: 0.0268 (0.0425)  time: 6.1783  data: 0.0203  max mem: 8558
# Epoch: [0]  [210/546]  eta: 0:28:56  lr: 0.001939  loss: 0.2303 (0.4107)  loss_classifier: 0.0652 (0.1939)  loss_box_reg: 0.1113 (0.1096)  loss_objectness: 0.0059 (0.0652)  loss_rpn_box_reg: 0.0280 (0.0419)  time: 5.9750  data: 0.0220  max mem: 8558
# Epoch: [0]  [220/546]  eta: 0:28:19  lr: 0.002030  loss: 0.2345 (0.4035)  loss_classifier: 0.0763 (0.1893)  loss_box_reg: 0.1232 (0.1103)  loss_objectness: 0.0097 (0.0629)  loss_rpn_box_reg: 0.0174 (0.0410)  time: 5.5516  data: 0.0211  max mem: 8558
# Epoch: [0]  [230/546]  eta: 0:27:25  lr: 0.002122  loss: 0.1928 (0.3947)  loss_classifier: 0.0674 (0.1838)  loss_box_reg: 0.0904 (0.1095)  loss_objectness: 0.0074 (0.0605)  loss_rpn_box_reg: 0.0182 (0.0409)  time: 5.6119  data: 0.0200  max mem: 8558
# Epoch: [0]  [240/546]  eta: 0:26:30  lr: 0.002214  loss: 0.1620 (0.3871)  loss_classifier: 0.0565 (0.1793)  loss_box_reg: 0.0734 (0.1091)  loss_objectness: 0.0073 (0.0583)  loss_rpn_box_reg: 0.0199 (0.0404)  time: 5.0425  data: 0.0185  max mem: 8558
# Epoch: [0]  [250/546]  eta: 0:25:47  lr: 0.002305  loss: 0.1606 (0.3796)  loss_classifier: 0.0495 (0.1747)  loss_box_reg: 0.0746 (0.1082)  loss_objectness: 0.0045 (0.0563)  loss_rpn_box_reg: 0.0250 (0.0404)  time: 5.4552  data: 0.0177  max mem: 8558
# Epoch: [0]  [260/546]  eta: 0:25:01  lr: 0.002397  loss: 0.1942 (0.3732)  loss_classifier: 0.0522 (0.1709)  loss_box_reg: 0.0712 (0.1076)  loss_objectness: 0.0042 (0.0544)  loss_rpn_box_reg: 0.0293 (0.0403)  time: 5.8777  data: 0.0193  max mem: 8558
# Epoch: [0]  [270/546]  eta: 0:23:58  lr: 0.002489  loss: 0.1726 (0.3658)  loss_classifier: 0.0518 (0.1667)  loss_box_reg: 0.0682 (0.1065)  loss_objectness: 0.0040 (0.0526)  loss_rpn_box_reg: 0.0245 (0.0400)  time: 4.9952  data: 0.0205  max mem: 8558
# Epoch: [0]  [280/546]  eta: 0:22:54  lr: 0.002580  loss: 0.1320 (0.3589)  loss_classifier: 0.0470 (0.1629)  loss_box_reg: 0.0596 (0.1056)  loss_objectness: 0.0036 (0.0508)  loss_rpn_box_reg: 0.0181 (0.0395)  time: 4.0945  data: 0.0224  max mem: 8558
# Epoch: [0]  [290/546]  eta: 0:21:51  lr: 0.002672  loss: 0.1411 (0.3530)  loss_classifier: 0.0470 (0.1594)  loss_box_reg: 0.0608 (0.1052)  loss_objectness: 0.0022 (0.0492)  loss_rpn_box_reg: 0.0204 (0.0392)  time: 3.9521  data: 0.0199  max mem: 8558
# Epoch: [0]  [300/546]  eta: 0:20:50  lr: 0.002764  loss: 0.1625 (0.3476)  loss_classifier: 0.0498 (0.1561)  loss_box_reg: 0.0608 (0.1042)  loss_objectness: 0.0028 (0.0481)  loss_rpn_box_reg: 0.0220 (0.0393)  time: 3.9057  data: 0.0193  max mem: 8558
# Epoch: [0]  [310/546]  eta: 0:19:55  lr: 0.002855  loss: 0.1727 (0.3436)  loss_classifier: 0.0494 (0.1534)  loss_box_reg: 0.0664 (0.1038)  loss_objectness: 0.0079 (0.0469)  loss_rpn_box_reg: 0.0193 (0.0395)  time: 4.1911  data: 0.0228  max mem: 8558
# Epoch: [0]  [320/546]  eta: 0:19:12  lr: 0.002947  loss: 0.1727 (0.3381)  loss_classifier: 0.0491 (0.1502)  loss_box_reg: 0.0706 (0.1028)  loss_objectness: 0.0048 (0.0456)  loss_rpn_box_reg: 0.0262 (0.0396)  time: 5.3409  data: 0.0231  max mem: 8558
# Epoch: [0]  [330/546]  eta: 0:18:27  lr: 0.003039  loss: 0.1564 (0.3334)  loss_classifier: 0.0503 (0.1475)  loss_box_reg: 0.0617 (0.1021)  loss_objectness: 0.0033 (0.0444)  loss_rpn_box_reg: 0.0262 (0.0394)  time: 6.1423  data: 0.0195  max mem: 8558
# Epoch: [0]  [340/546]  eta: 0:17:40  lr: 0.003130  loss: 0.1650 (0.3295)  loss_classifier: 0.0580 (0.1454)  loss_box_reg: 0.0645 (0.1015)  loss_objectness: 0.0062 (0.0433)  loss_rpn_box_reg: 0.0216 (0.0392)  time: 5.9210  data: 0.0200  max mem: 8558
# Epoch: [0]  [350/546]  eta: 0:16:52  lr: 0.003222  loss: 0.1533 (0.3251)  loss_classifier: 0.0580 (0.1429)  loss_box_reg: 0.0645 (0.1008)  loss_objectness: 0.0029 (0.0422)  loss_rpn_box_reg: 0.0314 (0.0392)  time: 5.7786  data: 0.0214  max mem: 8558
# Epoch: [0]  [360/546]  eta: 0:16:02  lr: 0.003314  loss: 0.1457 (0.3211)  loss_classifier: 0.0500 (0.1406)  loss_box_reg: 0.0607 (0.1002)  loss_objectness: 0.0019 (0.0412)  loss_rpn_box_reg: 0.0277 (0.0391)  time: 5.6432  data: 0.0190  max mem: 8558
# Epoch: [0]  [370/546]  eta: 0:15:08  lr: 0.003405  loss: 0.1341 (0.3166)  loss_classifier: 0.0543 (0.1384)  loss_box_reg: 0.0644 (0.0995)  loss_objectness: 0.0031 (0.0402)  loss_rpn_box_reg: 0.0187 (0.0386)  time: 5.0577  data: 0.0190  max mem: 8558
# Epoch: [0]  [380/546]  eta: 0:14:20  lr: 0.003497  loss: 0.1341 (0.3124)  loss_classifier: 0.0523 (0.1361)  loss_box_reg: 0.0557 (0.0985)  loss_objectness: 0.0039 (0.0393)  loss_rpn_box_reg: 0.0167 (0.0385)  time: 5.3335  data: 0.0217  max mem: 8558
# Epoch: [0]  [390/546]  eta: 0:13:25  lr: 0.003589  loss: 0.1435 (0.3093)  loss_classifier: 0.0450 (0.1344)  loss_box_reg: 0.0554 (0.0981)  loss_objectness: 0.0045 (0.0384)  loss_rpn_box_reg: 0.0174 (0.0385)  time: 5.2368  data: 0.0212  max mem: 8558
# Epoch: [0]  [400/546]  eta: 0:12:35  lr: 0.003680  loss: 0.1889 (0.3067)  loss_classifier: 0.0604 (0.1327)  loss_box_reg: 0.0672 (0.0983)  loss_objectness: 0.0027 (0.0376)  loss_rpn_box_reg: 0.0174 (0.0382)  time: 5.0409  data: 0.0194  max mem: 8558
# Epoch: [0]  [410/546]  eta: 0:11:49  lr: 0.003772  loss: 0.1752 (0.3042)  loss_classifier: 0.0604 (0.1314)  loss_box_reg: 0.0647 (0.0976)  loss_objectness: 0.0021 (0.0368)  loss_rpn_box_reg: 0.0259 (0.0385)  time: 6.1867  data: 0.0205  max mem: 8558
# Epoch: [0]  [420/546]  eta: 0:10:59  lr: 0.003864  loss: 0.1531 (0.3009)  loss_classifier: 0.0494 (0.1295)  loss_box_reg: 0.0520 (0.0969)  loss_objectness: 0.0035 (0.0361)  loss_rpn_box_reg: 0.0335 (0.0384)  time: 6.3637  data: 0.0205  max mem: 8558
# Epoch: [0]  [430/546]  eta: 0:10:03  lr: 0.003955  loss: 0.1450 (0.2973)  loss_classifier: 0.0468 (0.1276)  loss_box_reg: 0.0586 (0.0965)  loss_objectness: 0.0034 (0.0353)  loss_rpn_box_reg: 0.0158 (0.0379)  time: 4.9515  data: 0.0165  max mem: 8558
# Epoch: [0]  [440/546]  eta: 0:09:09  lr: 0.004047  loss: 0.1450 (0.2955)  loss_classifier: 0.0616 (0.1267)  loss_box_reg: 0.0763 (0.0966)  loss_objectness: 0.0019 (0.0346)  loss_rpn_box_reg: 0.0114 (0.0376)  time: 4.1161  data: 0.0155  max mem: 8558
# Epoch: [0]  [450/546]  eta: 0:08:18  lr: 0.004138  loss: 0.1714 (0.2929)  loss_classifier: 0.0636 (0.1254)  loss_box_reg: 0.0746 (0.0963)  loss_objectness: 0.0022 (0.0339)  loss_rpn_box_reg: 0.0195 (0.0373)  time: 5.0074  data: 0.0187  max mem: 8558
# Epoch: [0]  [460/546]  eta: 0:07:24  lr: 0.004230  loss: 0.1173 (0.2891)  loss_classifier: 0.0479 (0.1235)  loss_box_reg: 0.0417 (0.0950)  loss_objectness: 0.0025 (0.0333)  loss_rpn_box_reg: 0.0205 (0.0373)  time: 4.8895  data: 0.0197  max mem: 8558
# Epoch: [0]  [470/546]  eta: 0:06:35  lr: 0.004322  loss: 0.1145 (0.2865)  loss_classifier: 0.0411 (0.1221)  loss_box_reg: 0.0416 (0.0947)  loss_objectness: 0.0025 (0.0327)  loss_rpn_box_reg: 0.0177 (0.0371)  time: 5.4157  data: 0.0216  max mem: 8558
# Epoch: [0]  [480/546]  eta: 0:05:42  lr: 0.004413  loss: 0.1595 (0.2847)  loss_classifier: 0.0567 (0.1210)  loss_box_reg: 0.0845 (0.0947)  loss_objectness: 0.0017 (0.0322)  loss_rpn_box_reg: 0.0165 (0.0368)  time: 5.7445  data: 0.0233  max mem: 8558
# Epoch: [0]  [490/546]  eta: 0:04:52  lr: 0.004505  loss: 0.1625 (0.2821)  loss_classifier: 0.0523 (0.1197)  loss_box_reg: 0.0722 (0.0941)  loss_objectness: 0.0023 (0.0316)  loss_rpn_box_reg: 0.0187 (0.0368)  time: 5.6450  data: 0.0215  max mem: 8558
# Epoch: [0]  [500/546]  eta: 0:04:00  lr: 0.004597  loss: 0.1406 (0.2800)  loss_classifier: 0.0465 (0.1186)  loss_box_reg: 0.0549 (0.0939)  loss_objectness: 0.0028 (0.0310)  loss_rpn_box_reg: 0.0193 (0.0365)  time: 5.8702  data: 0.0199  max mem: 8558
# Epoch: [0]  [510/546]  eta: 0:03:08  lr: 0.004688  loss: 0.1327 (0.2779)  loss_classifier: 0.0522 (0.1175)  loss_box_reg: 0.0629 (0.0937)  loss_objectness: 0.0019 (0.0304)  loss_rpn_box_reg: 0.0173 (0.0363)  time: 5.8487  data: 0.0193  max mem: 8558
# Epoch: [0]  [520/546]  eta: 0:02:16  lr: 0.004780  loss: 0.1444 (0.2761)  loss_classifier: 0.0569 (0.1166)  loss_box_reg: 0.0549 (0.0935)  loss_objectness: 0.0015 (0.0299)  loss_rpn_box_reg: 0.0238 (0.0362)  time: 6.4422  data: 0.0232  max mem: 8558
# Epoch: [0]  [530/546]  eta: 0:01:24  lr: 0.004872  loss: 0.1455 (0.2738)  loss_classifier: 0.0562 (0.1155)  loss_box_reg: 0.0549 (0.0930)  loss_objectness: 0.0020 (0.0294)  loss_rpn_box_reg: 0.0258 (0.0360)  time: 5.9416  data: 0.0253  max mem: 8558
# Epoch: [0]  [540/546]  eta: 0:00:31  lr: 0.004963  loss: 0.1379 (0.2715)  loss_classifier: 0.0548 (0.1144)  loss_box_reg: 0.0538 (0.0924)  loss_objectness: 0.0020 (0.0289)  loss_rpn_box_reg: 0.0184 (0.0359)  time: 6.1060  data: 0.0247  max mem: 8558
# Epoch: [0]  [545/546]  eta: 0:00:05  lr: 0.005000  loss: 0.1455 (0.2707)  loss_classifier: 0.0460 (0.1139)  loss_box_reg: 0.0564 (0.0923)  loss_objectness: 0.0019 (0.0287)  loss_rpn_box_reg: 0.0258 (0.0358)  time: 6.4105  data: 0.0233  max mem: 8558
# Epoch: [0] Total time: 0:48:11 (5.2957 s / it)
# val:
# Epoch: [0]  [  0/182]  eta: 0:04:25  lr: 0.000005  loss: 0.2249 (0.2249)  loss_classifier: 0.0847 (0.0847)  loss_box_reg: 0.1312 (0.1312)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0082 (0.0082)  time: 1.4577  data: 0.0214  max mem: 8558
# Epoch: [0]  [ 10/182]  eta: 0:06:46  lr: 0.000005  loss: 0.1192 (0.1467)  loss_classifier: 0.0472 (0.0486)  loss_box_reg: 0.0545 (0.0651)  loss_objectness: 0.0008 (0.0058)  loss_rpn_box_reg: 0.0209 (0.0272)  time: 2.3607  data: 0.0221  max mem: 9572
# Epoch: [0]  [ 20/182]  eta: 0:06:00  lr: 0.000005  loss: 0.1135 (0.1438)  loss_classifier: 0.0365 (0.0478)  loss_box_reg: 0.0473 (0.0660)  loss_objectness: 0.0026 (0.0054)  loss_rpn_box_reg: 0.0209 (0.0246)  time: 2.2658  data: 0.0207  max mem: 9572
# Epoch: [0]  [ 30/182]  eta: 0:05:30  lr: 0.000005  loss: 0.1156 (0.1493)  loss_classifier: 0.0373 (0.0505)  loss_box_reg: 0.0412 (0.0666)  loss_objectness: 0.0013 (0.0052)  loss_rpn_box_reg: 0.0231 (0.0269)  time: 2.0699  data: 0.0195  max mem: 10110
# Epoch: [0]  [ 40/182]  eta: 0:05:11  lr: 0.000005  loss: 0.1339 (0.1469)  loss_classifier: 0.0398 (0.0486)  loss_box_reg: 0.0537 (0.0649)  loss_objectness: 0.0013 (0.0047)  loss_rpn_box_reg: 0.0269 (0.0288)  time: 2.1535  data: 0.0196  max mem: 10290
# Epoch: [0]  [ 50/182]  eta: 0:04:43  lr: 0.000005  loss: 0.1339 (0.1446)  loss_classifier: 0.0366 (0.0474)  loss_box_reg: 0.0547 (0.0658)  loss_objectness: 0.0015 (0.0043)  loss_rpn_box_reg: 0.0192 (0.0271)  time: 2.1144  data: 0.0205  max mem: 10290
# Epoch: [0]  [ 60/182]  eta: 0:04:19  lr: 0.000005  loss: 0.1373 (0.1525)  loss_classifier: 0.0441 (0.0492)  loss_box_reg: 0.0547 (0.0655)  loss_objectness: 0.0019 (0.0046)  loss_rpn_box_reg: 0.0258 (0.0333)  time: 1.9863  data: 0.0229  max mem: 10290
# Epoch: [0]  [ 70/182]  eta: 0:03:52  lr: 0.000005  loss: 0.1364 (0.1506)  loss_classifier: 0.0441 (0.0487)  loss_box_reg: 0.0481 (0.0652)  loss_objectness: 0.0023 (0.0043)  loss_rpn_box_reg: 0.0267 (0.0324)  time: 1.8803  data: 0.0250  max mem: 10290
# Epoch: [0]  [ 80/182]  eta: 0:03:30  lr: 0.000005  loss: 0.1147 (0.1482)  loss_classifier: 0.0348 (0.0476)  loss_box_reg: 0.0466 (0.0643)  loss_objectness: 0.0024 (0.0042)  loss_rpn_box_reg: 0.0229 (0.0320)  time: 1.8861  data: 0.0224  max mem: 10290
# Epoch: [0]  [ 90/182]  eta: 0:03:17  lr: 0.000005  loss: 0.1499 (0.1548)  loss_classifier: 0.0401 (0.0498)  loss_box_reg: 0.0499 (0.0667)  loss_objectness: 0.0024 (0.0043)  loss_rpn_box_reg: 0.0302 (0.0340)  time: 2.3805  data: 0.0198  max mem: 10656
# Epoch: [0]  [100/182]  eta: 0:02:55  lr: 0.000005  loss: 0.1610 (0.1555)  loss_classifier: 0.0484 (0.0497)  loss_box_reg: 0.0707 (0.0677)  loss_objectness: 0.0033 (0.0045)  loss_rpn_box_reg: 0.0316 (0.0336)  time: 2.4181  data: 0.0221  max mem: 10656
# Epoch: [0]  [110/182]  eta: 0:02:31  lr: 0.000005  loss: 0.1487 (0.1556)  loss_classifier: 0.0438 (0.0497)  loss_box_reg: 0.0693 (0.0678)  loss_objectness: 0.0022 (0.0044)  loss_rpn_box_reg: 0.0210 (0.0336)  time: 1.9611  data: 0.0233  max mem: 10656
# Epoch: [0]  [120/182]  eta: 0:02:10  lr: 0.000005  loss: 0.1492 (0.1553)  loss_classifier: 0.0349 (0.0498)  loss_box_reg: 0.0465 (0.0675)  loss_objectness: 0.0015 (0.0045)  loss_rpn_box_reg: 0.0316 (0.0336)  time: 1.9991  data: 0.0224  max mem: 10656
# Epoch: [0]  [130/182]  eta: 0:01:48  lr: 0.000005  loss: 0.1492 (0.1565)  loss_classifier: 0.0459 (0.0505)  loss_box_reg: 0.0534 (0.0684)  loss_objectness: 0.0019 (0.0044)  loss_rpn_box_reg: 0.0303 (0.0332)  time: 2.0053  data: 0.0217  max mem: 10656
# Epoch: [0]  [140/182]  eta: 0:01:28  lr: 0.000005  loss: 0.1573 (0.1581)  loss_classifier: 0.0459 (0.0510)  loss_box_reg: 0.0596 (0.0691)  loss_objectness: 0.0021 (0.0045)  loss_rpn_box_reg: 0.0236 (0.0336)  time: 2.0196  data: 0.0237  max mem: 10656
# Epoch: [0]  [150/182]  eta: 0:01:06  lr: 0.000005  loss: 0.1652 (0.1618)  loss_classifier: 0.0482 (0.0524)  loss_box_reg: 0.0659 (0.0706)  loss_objectness: 0.0050 (0.0047)  loss_rpn_box_reg: 0.0343 (0.0340)  time: 2.0940  data: 0.0250  max mem: 10656
# Epoch: [0]  [160/182]  eta: 0:00:45  lr: 0.000005  loss: 0.1546 (0.1614)  loss_classifier: 0.0649 (0.0527)  loss_box_reg: 0.0626 (0.0706)  loss_objectness: 0.0025 (0.0045)  loss_rpn_box_reg: 0.0213 (0.0336)  time: 1.9670  data: 0.0221  max mem: 10844
# Epoch: [0]  [170/182]  eta: 0:00:24  lr: 0.000005  loss: 0.1698 (0.1650)  loss_classifier: 0.0562 (0.0539)  loss_box_reg: 0.0626 (0.0723)  loss_objectness: 0.0024 (0.0048)  loss_rpn_box_reg: 0.0187 (0.0341)  time: 2.0010  data: 0.0200  max mem: 10844
# Epoch: [0]  [180/182]  eta: 0:00:04  lr: 0.000005  loss: 0.1432 (0.1623)  loss_classifier: 0.0455 (0.0532)  loss_box_reg: 0.0441 (0.0707)  loss_objectness: 0.0026 (0.0047)  loss_rpn_box_reg: 0.0252 (0.0337)  time: 1.9592  data: 0.0206  max mem: 10844
# Epoch: [0]  [181/182]  eta: 0:00:02  lr: 0.000005  loss: 0.1427 (0.1619)  loss_classifier: 0.0454 (0.0531)  loss_box_reg: 0.0435 (0.0705)  loss_objectness: 0.0022 (0.0047)  loss_rpn_box_reg: 0.0252 (0.0337)  time: 1.9388  data: 0.0213  max mem: 10844
# Epoch: [0] Total time: 0:06:16 (2.0674 s / it)
# Epoch 1/1
# ----------
# train:
# Epoch: [1]  [  0/546]  eta: 2:19:55  lr: 0.000005  loss: 0.1370 (0.1370)  loss_classifier: 0.0499 (0.0499)  loss_box_reg: 0.0644 (0.0644)  loss_objectness: 0.0040 (0.0040)  loss_rpn_box_reg: 0.0186 (0.0186)  time: 15.3756  data: 0.0090  max mem: 10844
# Epoch: [1]  [ 10/546]  eta: 1:03:14  lr: 0.000005  loss: 0.1132 (0.1363)  loss_classifier: 0.0324 (0.0390)  loss_box_reg: 0.0494 (0.0631)  loss_objectness: 0.0023 (0.0030)  loss_rpn_box_reg: 0.0190 (0.0313)  time: 7.0793  data: 0.0119  max mem: 10844
# Epoch: [1]  [ 20/546]  eta: 0:56:08  lr: 0.000005  loss: 0.1132 (0.1305)  loss_classifier: 0.0314 (0.0380)  loss_box_reg: 0.0445 (0.0551)  loss_objectness: 0.0023 (0.0039)  loss_rpn_box_reg: 0.0276 (0.0336)  time: 5.9553  data: 0.0117  max mem: 10844
# Epoch: [1]  [ 30/546]  eta: 0:55:09  lr: 0.000005  loss: 0.1267 (0.1301)  loss_classifier: 0.0376 (0.0385)  loss_box_reg: 0.0440 (0.0527)  loss_objectness: 0.0024 (0.0035)  loss_rpn_box_reg: 0.0284 (0.0353)  time: 6.0481  data: 0.0104  max mem: 10844
# Epoch: [1]  [ 40/546]  eta: 0:53:02  lr: 0.000005  loss: 0.1197 (0.1305)  loss_classifier: 0.0364 (0.0400)  loss_box_reg: 0.0440 (0.0536)  loss_objectness: 0.0031 (0.0041)  loss_rpn_box_reg: 0.0265 (0.0329)  time: 6.1706  data: 0.0105  max mem: 10844
# Epoch: [1]  [ 50/546]  eta: 0:52:34  lr: 0.000005  loss: 0.1220 (0.1411)  loss_classifier: 0.0378 (0.0435)  loss_box_reg: 0.0583 (0.0622)  loss_objectness: 0.0035 (0.0039)  loss_rpn_box_reg: 0.0238 (0.0315)  time: 6.2762  data: 0.0107  max mem: 10844
# Epoch: [1]  [ 60/546]  eta: 0:50:50  lr: 0.000005  loss: 0.1220 (0.1401)  loss_classifier: 0.0383 (0.0435)  loss_box_reg: 0.0535 (0.0606)  loss_objectness: 0.0015 (0.0041)  loss_rpn_box_reg: 0.0249 (0.0320)  time: 6.2525  data: 0.0101  max mem: 10844
# Epoch: [1]  [ 70/546]  eta: 0:49:51  lr: 0.000005  loss: 0.1288 (0.1446)  loss_classifier: 0.0397 (0.0453)  loss_box_reg: 0.0509 (0.0617)  loss_objectness: 0.0030 (0.0042)  loss_rpn_box_reg: 0.0311 (0.0334)  time: 6.0895  data: 0.0098  max mem: 10844
# Epoch: [1]  [ 80/546]  eta: 0:48:47  lr: 0.000005  loss: 0.1563 (0.1478)  loss_classifier: 0.0466 (0.0465)  loss_box_reg: 0.0673 (0.0636)  loss_objectness: 0.0019 (0.0040)  loss_rpn_box_reg: 0.0353 (0.0338)  time: 6.2944  data: 0.0099  max mem: 10844
# Epoch: [1]  [ 90/546]  eta: 0:46:12  lr: 0.000005  loss: 0.1563 (0.1484)  loss_classifier: 0.0466 (0.0467)  loss_box_reg: 0.0595 (0.0649)  loss_objectness: 0.0016 (0.0042)  loss_rpn_box_reg: 0.0215 (0.0327)  time: 5.3563  data: 0.0109  max mem: 10844
# Epoch: [1]  [100/546]  eta: 0:45:13  lr: 0.000005  loss: 0.1113 (0.1482)  loss_classifier: 0.0405 (0.0469)  loss_box_reg: 0.0483 (0.0649)  loss_objectness: 0.0016 (0.0040)  loss_rpn_box_reg: 0.0218 (0.0324)  time: 5.2852  data: 0.0104  max mem: 10844
# Epoch: [1]  [110/546]  eta: 0:43:30  lr: 0.000005  loss: 0.1140 (0.1490)  loss_classifier: 0.0418 (0.0470)  loss_box_reg: 0.0441 (0.0647)  loss_objectness: 0.0016 (0.0040)  loss_rpn_box_reg: 0.0252 (0.0332)  time: 5.5677  data: 0.0105  max mem: 10844
# Epoch: [1]  [120/546]  eta: 0:42:12  lr: 0.000005  loss: 0.1265 (0.1512)  loss_classifier: 0.0440 (0.0486)  loss_box_reg: 0.0441 (0.0660)  loss_objectness: 0.0027 (0.0042)  loss_rpn_box_reg: 0.0233 (0.0324)  time: 5.2429  data: 0.0112  max mem: 10844
# Epoch: [1]  [130/546]  eta: 0:40:56  lr: 0.000005  loss: 0.1263 (0.1510)  loss_classifier: 0.0479 (0.0489)  loss_box_reg: 0.0456 (0.0664)  loss_objectness: 0.0019 (0.0041)  loss_rpn_box_reg: 0.0168 (0.0316)  time: 5.4544  data: 0.0107  max mem: 10844
# Epoch: [1]  [140/546]  eta: 0:39:54  lr: 0.000005  loss: 0.1423 (0.1532)  loss_classifier: 0.0452 (0.0494)  loss_box_reg: 0.0543 (0.0671)  loss_objectness: 0.0009 (0.0043)  loss_rpn_box_reg: 0.0170 (0.0324)  time: 5.6034  data: 0.0125  max mem: 10844
# Epoch: [1]  [150/546]  eta: 0:39:04  lr: 0.000005  loss: 0.1388 (0.1544)  loss_classifier: 0.0391 (0.0501)  loss_box_reg: 0.0471 (0.0677)  loss_objectness: 0.0018 (0.0043)  loss_rpn_box_reg: 0.0198 (0.0323)  time: 6.0071  data: 0.0122  max mem: 10844
# Epoch: [1]  [160/546]  eta: 0:37:36  lr: 0.000005  loss: 0.1388 (0.1561)  loss_classifier: 0.0377 (0.0506)  loss_box_reg: 0.0588 (0.0696)  loss_objectness: 0.0025 (0.0044)  loss_rpn_box_reg: 0.0146 (0.0315)  time: 5.4926  data: 0.0128  max mem: 10844
# Epoch: [1]  [170/546]  eta: 0:36:09  lr: 0.000005  loss: 0.1762 (0.1575)  loss_classifier: 0.0537 (0.0513)  loss_box_reg: 0.0912 (0.0713)  loss_objectness: 0.0024 (0.0042)  loss_rpn_box_reg: 0.0123 (0.0307)  time: 4.6394  data: 0.0132  max mem: 10844
# Epoch: [1]  [180/546]  eta: 0:35:25  lr: 0.000005  loss: 0.1634 (0.1586)  loss_classifier: 0.0508 (0.0516)  loss_box_reg: 0.0797 (0.0718)  loss_objectness: 0.0015 (0.0041)  loss_rpn_box_reg: 0.0160 (0.0312)  time: 5.4945  data: 0.0096  max mem: 10844
# Epoch: [1]  [190/546]  eta: 0:35:03  lr: 0.000005  loss: 0.1756 (0.1624)  loss_classifier: 0.0591 (0.0532)  loss_box_reg: 0.0797 (0.0736)  loss_objectness: 0.0013 (0.0041)  loss_rpn_box_reg: 0.0232 (0.0314)  time: 7.0947  data: 0.0100  max mem: 10844
# Epoch: [1]  [200/546]  eta: 0:33:53  lr: 0.000005  loss: 0.1461 (0.1603)  loss_classifier: 0.0430 (0.0525)  loss_box_reg: 0.0522 (0.0727)  loss_objectness: 0.0017 (0.0041)  loss_rpn_box_reg: 0.0143 (0.0310)  time: 6.4977  data: 0.0119  max mem: 10844
# Epoch: [1]  [210/546]  eta: 0:33:16  lr: 0.000005  loss: 0.1101 (0.1588)  loss_classifier: 0.0356 (0.0521)  loss_box_reg: 0.0416 (0.0720)  loss_objectness: 0.0016 (0.0040)  loss_rpn_box_reg: 0.0145 (0.0308)  time: 6.2503  data: 0.0122  max mem: 10844
# Epoch: [1]  [220/546]  eta: 0:32:09  lr: 0.000005  loss: 0.1154 (0.1583)  loss_classifier: 0.0366 (0.0520)  loss_box_reg: 0.0461 (0.0719)  loss_objectness: 0.0021 (0.0040)  loss_rpn_box_reg: 0.0161 (0.0304)  time: 6.3452  data: 0.0130  max mem: 10844
# Epoch: [1]  [230/546]  eta: 0:31:11  lr: 0.000005  loss: 0.1430 (0.1593)  loss_classifier: 0.0366 (0.0524)  loss_box_reg: 0.0463 (0.0720)  loss_objectness: 0.0021 (0.0040)  loss_rpn_box_reg: 0.0189 (0.0308)  time: 5.7113  data: 0.0119  max mem: 10844
# Epoch: [1]  [240/546]  eta: 0:30:15  lr: 0.000005  loss: 0.1273 (0.1581)  loss_classifier: 0.0374 (0.0522)  loss_box_reg: 0.0460 (0.0713)  loss_objectness: 0.0031 (0.0040)  loss_rpn_box_reg: 0.0222 (0.0306)  time: 6.0717  data: 0.0118  max mem: 10844
# Epoch: [1]  [250/546]  eta: 0:29:13  lr: 0.000005  loss: 0.1139 (0.1575)  loss_classifier: 0.0330 (0.0519)  loss_box_reg: 0.0444 (0.0709)  loss_objectness: 0.0031 (0.0041)  loss_rpn_box_reg: 0.0189 (0.0305)  time: 5.9431  data: 0.0120  max mem: 10844
# Epoch: [1]  [260/546]  eta: 0:28:15  lr: 0.000005  loss: 0.1328 (0.1569)  loss_classifier: 0.0318 (0.0516)  loss_box_reg: 0.0388 (0.0707)  loss_objectness: 0.0025 (0.0041)  loss_rpn_box_reg: 0.0183 (0.0305)  time: 5.8965  data: 0.0120  max mem: 10844
# Epoch: [1]  [270/546]  eta: 0:27:30  lr: 0.000005  loss: 0.1423 (0.1571)  loss_classifier: 0.0487 (0.0517)  loss_box_reg: 0.0494 (0.0706)  loss_objectness: 0.0031 (0.0041)  loss_rpn_box_reg: 0.0152 (0.0307)  time: 6.6776  data: 0.0121  max mem: 10844
# Epoch: [1]  [280/546]  eta: 0:26:28  lr: 0.000005  loss: 0.1579 (0.1577)  loss_classifier: 0.0506 (0.0518)  loss_box_reg: 0.0551 (0.0709)  loss_objectness: 0.0031 (0.0041)  loss_rpn_box_reg: 0.0238 (0.0309)  time: 6.5449  data: 0.0110  max mem: 10844
# Epoch: [1]  [290/546]  eta: 0:25:26  lr: 0.000005  loss: 0.1097 (0.1562)  loss_classifier: 0.0358 (0.0514)  loss_box_reg: 0.0550 (0.0703)  loss_objectness: 0.0015 (0.0040)  loss_rpn_box_reg: 0.0146 (0.0305)  time: 5.7666  data: 0.0105  max mem: 10844
# Epoch: [1]  [300/546]  eta: 0:24:29  lr: 0.000005  loss: 0.0958 (0.1545)  loss_classifier: 0.0318 (0.0508)  loss_box_reg: 0.0467 (0.0693)  loss_objectness: 0.0015 (0.0040)  loss_rpn_box_reg: 0.0145 (0.0304)  time: 6.0073  data: 0.0106  max mem: 10844
# Epoch: [1]  [310/546]  eta: 0:24:10  lr: 0.000005  loss: 0.1064 (0.1552)  loss_classifier: 0.0425 (0.0512)  loss_box_reg: 0.0478 (0.0697)  loss_objectness: 0.0028 (0.0040)  loss_rpn_box_reg: 0.0158 (0.0302)  time: 8.7701  data: 0.0154  max mem: 10844
# Epoch: [1]  [320/546]  eta: 0:23:39  lr: 0.000005  loss: 0.1261 (0.1555)  loss_classifier: 0.0489 (0.0512)  loss_box_reg: 0.0554 (0.0702)  loss_objectness: 0.0029 (0.0040)  loss_rpn_box_reg: 0.0156 (0.0301)  time: 10.8784  data: 0.0184  max mem: 10844
# Epoch: [1]  [330/546]  eta: 0:23:04  lr: 0.000005  loss: 0.1261 (0.1559)  loss_classifier: 0.0506 (0.0512)  loss_box_reg: 0.0579 (0.0702)  loss_objectness: 0.0024 (0.0041)  loss_rpn_box_reg: 0.0156 (0.0303)  time: 10.5119  data: 0.0191  max mem: 10844
# Epoch: [1]  [340/546]  eta: 0:22:36  lr: 0.000005  loss: 0.1827 (0.1579)  loss_classifier: 0.0594 (0.0520)  loss_box_reg: 0.0919 (0.0714)  loss_objectness: 0.0022 (0.0041)  loss_rpn_box_reg: 0.0208 (0.0304)  time: 11.4640  data: 0.0197  max mem: 10844
# Epoch: [1]  [350/546]  eta: 0:21:49  lr: 0.000005  loss: 0.1721 (0.1583)  loss_classifier: 0.0553 (0.0523)  loss_box_reg: 0.0967 (0.0716)  loss_objectness: 0.0021 (0.0040)  loss_rpn_box_reg: 0.0202 (0.0303)  time: 11.2188  data: 0.0183  max mem: 10844
# Epoch: [1]  [360/546]  eta: 0:21:01  lr: 0.000005  loss: 0.1362 (0.1572)  loss_classifier: 0.0422 (0.0517)  loss_box_reg: 0.0488 (0.0713)  loss_objectness: 0.0015 (0.0040)  loss_rpn_box_reg: 0.0182 (0.0301)  time: 10.1860  data: 0.0188  max mem: 10844
# Epoch: [1]  [370/546]  eta: 0:20:09  lr: 0.000005  loss: 0.1198 (0.1565)  loss_classifier: 0.0357 (0.0516)  loss_box_reg: 0.0416 (0.0710)  loss_objectness: 0.0012 (0.0040)  loss_rpn_box_reg: 0.0160 (0.0298)  time: 10.2260  data: 0.0179  max mem: 10844
# Epoch: [1]  [380/546]  eta: 0:19:30  lr: 0.000005  loss: 0.1224 (0.1563)  loss_classifier: 0.0416 (0.0516)  loss_box_reg: 0.0476 (0.0708)  loss_objectness: 0.0011 (0.0039)  loss_rpn_box_reg: 0.0165 (0.0300)  time: 11.8700  data: 0.0226  max mem: 10844
# Epoch: [1]  [390/546]  eta: 0:18:35  lr: 0.000005  loss: 0.1010 (0.1558)  loss_classifier: 0.0389 (0.0513)  loss_box_reg: 0.0378 (0.0704)  loss_objectness: 0.0009 (0.0039)  loss_rpn_box_reg: 0.0273 (0.0302)  time: 12.2488  data: 0.0244  max mem: 10844
# Epoch: [1]  [400/546]  eta: 0:17:36  lr: 0.000005  loss: 0.1212 (0.1557)  loss_classifier: 0.0364 (0.0513)  loss_box_reg: 0.0471 (0.0705)  loss_objectness: 0.0013 (0.0040)  loss_rpn_box_reg: 0.0183 (0.0300)  time: 10.7809  data: 0.0214  max mem: 10844
# Epoch: [1]  [410/546]  eta: 0:16:36  lr: 0.000005  loss: 0.1212 (0.1553)  loss_classifier: 0.0382 (0.0511)  loss_box_reg: 0.0588 (0.0703)  loss_objectness: 0.0018 (0.0039)  loss_rpn_box_reg: 0.0160 (0.0299)  time: 10.8934  data: 0.0282  max mem: 10844
# Epoch: [1]  [420/546]  eta: 0:15:33  lr: 0.000005  loss: 0.1158 (0.1553)  loss_classifier: 0.0379 (0.0511)  loss_box_reg: 0.0573 (0.0703)  loss_objectness: 0.0018 (0.0039)  loss_rpn_box_reg: 0.0160 (0.0300)  time: 10.8580  data: 0.0254  max mem: 10844
# Epoch: [1]  [430/546]  eta: 0:14:29  lr: 0.000005  loss: 0.1489 (0.1554)  loss_classifier: 0.0493 (0.0512)  loss_box_reg: 0.0562 (0.0703)  loss_objectness: 0.0014 (0.0039)  loss_rpn_box_reg: 0.0161 (0.0299)  time: 10.9621  data: 0.0194  max mem: 10844
# Epoch: [1]  [440/546]  eta: 0:13:24  lr: 0.000005  loss: 0.1310 (0.1548)  loss_classifier: 0.0379 (0.0509)  loss_box_reg: 0.0526 (0.0698)  loss_objectness: 0.0013 (0.0039)  loss_rpn_box_reg: 0.0185 (0.0303)  time: 11.3628  data: 0.0248  max mem: 10844
# Epoch: [1]  [450/546]  eta: 0:12:16  lr: 0.000005  loss: 0.1286 (0.1546)  loss_classifier: 0.0379 (0.0509)  loss_box_reg: 0.0479 (0.0697)  loss_objectness: 0.0019 (0.0039)  loss_rpn_box_reg: 0.0199 (0.0302)  time: 11.3668  data: 0.0303  max mem: 10844
# Epoch: [1]  [460/546]  eta: 0:11:11  lr: 0.000005  loss: 0.1531 (0.1548)  loss_classifier: 0.0448 (0.0509)  loss_box_reg: 0.0506 (0.0697)  loss_objectness: 0.0019 (0.0039)  loss_rpn_box_reg: 0.0278 (0.0304)  time: 12.7264  data: 0.0328  max mem: 10844
# Epoch: [1]  [470/546]  eta: 0:10:00  lr: 0.000005  loss: 0.1226 (0.1544)  loss_classifier: 0.0385 (0.0508)  loss_box_reg: 0.0455 (0.0694)  loss_objectness: 0.0023 (0.0039)  loss_rpn_box_reg: 0.0214 (0.0303)  time: 13.0287  data: 0.0273  max mem: 10844
# Epoch: [1]  [480/546]  eta: 0:08:48  lr: 0.000005  loss: 0.1169 (0.1543)  loss_classifier: 0.0387 (0.0509)  loss_box_reg: 0.0423 (0.0693)  loss_objectness: 0.0016 (0.0039)  loss_rpn_box_reg: 0.0172 (0.0303)  time: 12.6987  data: 0.0253  max mem: 10844
# Epoch: [1]  [490/546]  eta: 0:07:33  lr: 0.000005  loss: 0.1609 (0.1548)  loss_classifier: 0.0444 (0.0509)  loss_box_reg: 0.0449 (0.0694)  loss_objectness: 0.0015 (0.0039)  loss_rpn_box_reg: 0.0209 (0.0306)  time: 12.7183  data: 0.0312  max mem: 10844
# Epoch: [1]  [500/546]  eta: 0:06:16  lr: 0.000005  loss: 0.1462 (0.1544)  loss_classifier: 0.0398 (0.0507)  loss_box_reg: 0.0466 (0.0690)  loss_objectness: 0.0016 (0.0039)  loss_rpn_box_reg: 0.0354 (0.0308)  time: 12.1509  data: 0.0317  max mem: 10844
# Epoch: [1]  [510/546]  eta: 0:04:56  lr: 0.000005  loss: 0.1388 (0.1544)  loss_classifier: 0.0364 (0.0506)  loss_box_reg: 0.0466 (0.0690)  loss_objectness: 0.0017 (0.0039)  loss_rpn_box_reg: 0.0291 (0.0309)  time: 11.9442  data: 0.0311  max mem: 10844
# Epoch: [1]  [520/546]  eta: 0:03:35  lr: 0.000005  loss: 0.1374 (0.1541)  loss_classifier: 0.0364 (0.0505)  loss_box_reg: 0.0509 (0.0689)  loss_objectness: 0.0017 (0.0038)  loss_rpn_box_reg: 0.0205 (0.0308)  time: 10.9495  data: 0.0279  max mem: 10844
# Epoch: [1]  [530/546]  eta: 0:02:13  lr: 0.000005  loss: 0.1162 (0.1537)  loss_classifier: 0.0341 (0.0503)  loss_box_reg: 0.0478 (0.0689)  loss_objectness: 0.0032 (0.0039)  loss_rpn_box_reg: 0.0152 (0.0306)  time: 10.6832  data: 0.0233  max mem: 10844
# Epoch: [1]  [540/546]  eta: 0:00:50  lr: 0.000005  loss: 0.0979 (0.1533)  loss_classifier: 0.0381 (0.0503)  loss_box_reg: 0.0452 (0.0687)  loss_objectness: 0.0022 (0.0038)  loss_rpn_box_reg: 0.0133 (0.0305)  time: 10.8144  data: 0.0282  max mem: 10844
# Epoch: [1]  [545/546]  eta: 0:00:08  lr: 0.000005  loss: 0.0979 (0.1536)  loss_classifier: 0.0321 (0.0503)  loss_box_reg: 0.0452 (0.0688)  loss_objectness: 0.0016 (0.0039)  loss_rpn_box_reg: 0.0133 (0.0306)  time: 10.8926  data: 0.0289  max mem: 10844
# Epoch: [1] Total time: 1:16:30 (8.4082 s / it)
# val:
# Epoch: [1]  [  0/182]  eta: 0:09:36  lr: 0.000005  loss: 0.0652 (0.0652)  loss_classifier: 0.0193 (0.0193)  loss_box_reg: 0.0281 (0.0281)  loss_objectness: 0.0066 (0.0066)  loss_rpn_box_reg: 0.0111 (0.0111)  time: 3.1695  data: 0.0299  max mem: 10844
# Epoch: [1]  [ 10/182]  eta: 0:09:52  lr: 0.000005  loss: 0.1269 (0.1550)  loss_classifier: 0.0334 (0.0519)  loss_box_reg: 0.0482 (0.0750)  loss_objectness: 0.0009 (0.0026)  loss_rpn_box_reg: 0.0269 (0.0255)  time: 3.4458  data: 0.0251  max mem: 10844
# Epoch: [1]  [ 20/182]  eta: 0:09:18  lr: 0.000005  loss: 0.1279 (0.1476)  loss_classifier: 0.0400 (0.0483)  loss_box_reg: 0.0455 (0.0626)  loss_objectness: 0.0009 (0.0028)  loss_rpn_box_reg: 0.0277 (0.0339)  time: 3.4617  data: 0.0228  max mem: 10844
# Epoch: [1]  [ 30/182]  eta: 0:08:36  lr: 0.000005  loss: 0.1197 (0.1446)  loss_classifier: 0.0389 (0.0463)  loss_box_reg: 0.0416 (0.0587)  loss_objectness: 0.0014 (0.0036)  loss_rpn_box_reg: 0.0386 (0.0359)  time: 3.3707  data: 0.0216  max mem: 11016
# Epoch: [1]  [ 40/182]  eta: 0:07:57  lr: 0.000005  loss: 0.1156 (0.1526)  loss_classifier: 0.0383 (0.0499)  loss_box_reg: 0.0416 (0.0635)  loss_objectness: 0.0020 (0.0038)  loss_rpn_box_reg: 0.0334 (0.0355)  time: 3.2662  data: 0.0207  max mem: 11016
# Epoch: [1]  [ 50/182]  eta: 0:07:17  lr: 0.000005  loss: 0.1053 (0.1442)  loss_classifier: 0.0375 (0.0473)  loss_box_reg: 0.0445 (0.0599)  loss_objectness: 0.0017 (0.0037)  loss_rpn_box_reg: 0.0211 (0.0332)  time: 3.1952  data: 0.0178  max mem: 11016
# Epoch: [1]  [ 60/182]  eta: 0:06:40  lr: 0.000005  loss: 0.1155 (0.1514)  loss_classifier: 0.0381 (0.0514)  loss_box_reg: 0.0477 (0.0652)  loss_objectness: 0.0016 (0.0034)  loss_rpn_box_reg: 0.0179 (0.0315)  time: 3.1177  data: 0.0176  max mem: 11016
# Epoch: [1]  [ 70/182]  eta: 0:06:11  lr: 0.000005  loss: 0.1287 (0.1504)  loss_classifier: 0.0431 (0.0502)  loss_box_reg: 0.0549 (0.0643)  loss_objectness: 0.0022 (0.0034)  loss_rpn_box_reg: 0.0190 (0.0324)  time: 3.3240  data: 0.0189  max mem: 11016
# Epoch: [1]  [ 80/182]  eta: 0:05:36  lr: 0.000005  loss: 0.1287 (0.1519)  loss_classifier: 0.0396 (0.0502)  loss_box_reg: 0.0503 (0.0649)  loss_objectness: 0.0022 (0.0042)  loss_rpn_box_reg: 0.0208 (0.0326)  time: 3.3610  data: 0.0199  max mem: 11016
# Epoch: [1]  [ 90/182]  eta: 0:05:03  lr: 0.000005  loss: 0.1773 (0.1564)  loss_classifier: 0.0410 (0.0517)  loss_box_reg: 0.0540 (0.0676)  loss_objectness: 0.0011 (0.0040)  loss_rpn_box_reg: 0.0303 (0.0332)  time: 3.2099  data: 0.0196  max mem: 11016
# Epoch: [1]  [100/182]  eta: 0:04:30  lr: 0.000005  loss: 0.1893 (0.1598)  loss_classifier: 0.0516 (0.0527)  loss_box_reg: 0.0607 (0.0684)  loss_objectness: 0.0018 (0.0041)  loss_rpn_box_reg: 0.0336 (0.0346)  time: 3.2766  data: 0.0208  max mem: 11016
# Epoch: [1]  [110/182]  eta: 0:03:55  lr: 0.000005  loss: 0.1654 (0.1618)  loss_classifier: 0.0406 (0.0539)  loss_box_reg: 0.0607 (0.0691)  loss_objectness: 0.0028 (0.0043)  loss_rpn_box_reg: 0.0279 (0.0345)  time: 3.1730  data: 0.0289  max mem: 11016
# Epoch: [1]  [120/182]  eta: 0:03:22  lr: 0.000005  loss: 0.1211 (0.1602)  loss_classifier: 0.0422 (0.0534)  loss_box_reg: 0.0563 (0.0691)  loss_objectness: 0.0020 (0.0041)  loss_rpn_box_reg: 0.0172 (0.0336)  time: 3.1584  data: 0.0287  max mem: 11016
# Epoch: [1]  [130/182]  eta: 0:02:50  lr: 0.000005  loss: 0.1355 (0.1613)  loss_classifier: 0.0480 (0.0537)  loss_box_reg: 0.0563 (0.0699)  loss_objectness: 0.0020 (0.0043)  loss_rpn_box_reg: 0.0172 (0.0334)  time: 3.3272  data: 0.0215  max mem: 11016
# Epoch: [1]  [140/182]  eta: 0:02:17  lr: 0.000005  loss: 0.1565 (0.1616)  loss_classifier: 0.0481 (0.0535)  loss_box_reg: 0.0542 (0.0702)  loss_objectness: 0.0036 (0.0044)  loss_rpn_box_reg: 0.0232 (0.0335)  time: 3.2976  data: 0.0205  max mem: 11016
# Epoch: [1]  [150/182]  eta: 0:01:45  lr: 0.000005  loss: 0.1396 (0.1612)  loss_classifier: 0.0457 (0.0531)  loss_box_reg: 0.0478 (0.0700)  loss_objectness: 0.0028 (0.0045)  loss_rpn_box_reg: 0.0244 (0.0336)  time: 3.3413  data: 0.0198  max mem: 11016
# Epoch: [1]  [160/182]  eta: 0:01:12  lr: 0.000005  loss: 0.1356 (0.1599)  loss_classifier: 0.0415 (0.0528)  loss_box_reg: 0.0478 (0.0696)  loss_objectness: 0.0008 (0.0043)  loss_rpn_box_reg: 0.0244 (0.0332)  time: 3.3063  data: 0.0206  max mem: 11016
# Epoch: [1]  [170/182]  eta: 0:00:39  lr: 0.000005  loss: 0.1292 (0.1607)  loss_classifier: 0.0415 (0.0531)  loss_box_reg: 0.0507 (0.0701)  loss_objectness: 0.0008 (0.0043)  loss_rpn_box_reg: 0.0200 (0.0332)  time: 3.2263  data: 0.0222  max mem: 11016
# Epoch: [1]  [180/182]  eta: 0:00:06  lr: 0.000005  loss: 0.1292 (0.1593)  loss_classifier: 0.0405 (0.0527)  loss_box_reg: 0.0558 (0.0696)  loss_objectness: 0.0034 (0.0046)  loss_rpn_box_reg: 0.0194 (0.0324)  time: 3.0526  data: 0.0223  max mem: 11016
# Epoch: [1]  [181/182]  eta: 0:00:03  lr: 0.000005  loss: 0.1323 (0.1595)  loss_classifier: 0.0457 (0.0528)  loss_box_reg: 0.0572 (0.0698)  loss_objectness: 0.0020 (0.0046)  loss_rpn_box_reg: 0.0167 (0.0323)  time: 3.0576  data: 0.0224  max mem: 11016
# Epoch: [1] Total time: 0:09:51 (3.2479 s / it)
# ['training_output']

# %%
tl, od = training_loop(local_model, 
                       aug_train_data_loader, 
                       aug_val_data_loader, 
                       optimizer,
                       save_name = 'Models/CHR_ResNet',
                       device = torch.device('cuda'),
                       epochs=20)

dump(od, 'training_output')
# Out:
# Epoch 0/19
# ----------
# train:
# Epoch: [0]  [  0/534]  eta: 2:37:53  lr: 0.000000  loss: 0.1872 (0.1872)  loss_classifier: 0.0540 (0.0540)  loss_box_reg: 0.0663 (0.0663)  loss_objectness: 0.0022 (0.0022)  loss_rpn_box_reg: 0.0646 (0.0646)  time: 17.7411  data: 0.0178  max mem: 11403
# Epoch: [0]  [ 10/534]  eta: 2:00:30  lr: 0.000000  loss: 0.1216 (0.1832)  loss_classifier: 0.0378 (0.0626)  loss_box_reg: 0.0486 (0.0757)  loss_objectness: 0.0022 (0.0051)  loss_rpn_box_reg: 0.0248 (0.0397)  time: 13.7978  data: 0.0187  max mem: 11403
# Epoch: [0]  [ 20/534]  eta: 1:57:23  lr: 0.000000  loss: 0.1557 (0.2988)  loss_classifier: 0.0419 (0.0674)  loss_box_reg: 0.0486 (0.0747)  loss_objectness: 0.0037 (0.1065)  loss_rpn_box_reg: 0.0169 (0.0503)  time: 13.5024  data: 0.0192  max mem: 11403
# Epoch: [0]  [ 30/534]  eta: 1:49:58  lr: 0.000000  loss: 0.1570 (0.2563)  loss_classifier: 0.0463 (0.0626)  loss_box_reg: 0.0518 (0.0762)  loss_objectness: 0.0030 (0.0738)  loss_rpn_box_reg: 0.0142 (0.0438)  time: 12.7030  data: 0.0204  max mem: 11403
# Epoch: [0]  [ 40/534]  eta: 1:48:25  lr: 0.000000  loss: 0.1340 (0.2265)  loss_classifier: 0.0365 (0.0565)  loss_box_reg: 0.0518 (0.0725)  loss_objectness: 0.0024 (0.0576)  loss_rpn_box_reg: 0.0146 (0.0399)  time: 12.6078  data: 0.0213  max mem: 11403
# Epoch: [0]  [ 50/534]  eta: 1:47:00  lr: 0.000000  loss: 0.1460 (0.2205)  loss_classifier: 0.0365 (0.0586)  loss_box_reg: 0.0525 (0.0735)  loss_objectness: 0.0025 (0.0474)  loss_rpn_box_reg: 0.0188 (0.0411)  time: 13.5364  data: 0.0206  max mem: 11403
# Epoch: [0]  [ 60/534]  eta: 1:44:15  lr: 0.000000  loss: 0.1450 (0.2116)  loss_classifier: 0.0443 (0.0588)  loss_box_reg: 0.0497 (0.0748)  loss_objectness: 0.0020 (0.0401)  loss_rpn_box_reg: 0.0200 (0.0379)  time: 13.2553  data: 0.0211  max mem: 11403
# Epoch: [0]  [ 70/534]  eta: 1:40:57  lr: 0.000000  loss: 0.1234 (0.2044)  loss_classifier: 0.0432 (0.0592)  loss_box_reg: 0.0537 (0.0748)  loss_objectness: 0.0011 (0.0347)  loss_rpn_box_reg: 0.0165 (0.0356)  time: 12.5135  data: 0.0195  max mem: 11403
